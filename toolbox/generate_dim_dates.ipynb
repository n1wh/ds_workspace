# %%
import os
import datetime as dt
import calendar
from dateutil.relativedelta import relativedelta

import pandas as pd
from pandas.tseries.offsets import QuarterEnd, YearEnd

import holidays

# %% [markdown]
# # Initialize a dataframe with date range

# %%
start_period = '2000-01-01'
end_period = '2029-12-31'

date_list = pd.date_range(start=start_period, end=end_period).to_pydatetime().tolist()
df = pd.DataFrame(data=date_list, columns=['date_id'])
df.shape
# Out:
# (10958, 1)

# %%
df.head()
# Out:
#      date_id
# 0 2000-01-01
# 1 2000-01-02
# 2 2000-01-03
# 3 2000-01-04
# 4 2000-01-05

# %% [markdown]
# # Enrich it with datetime attributes

# %%
# %%time 

# init a list of holidays for every country, it will fill after the first request
us_holidays = holidays.US()
ua_holidays = holidays.UA()

# set prefixies
calendar = 'calendar'
fiscal = 'fiscal'

# basic attributes
df['month_name'] = df['date_id'].dt.strftime("%B")
df['weekday_name'] = df['date_id'].dt.strftime("%A")
df['day_of_month'] = df['date_id'].dt.day
df['day_of_year'] = df['date_id'].dt.day_of_year  # another approach .apply(lambda date: date.timetuple().tm_yday)
df['week_of_year'] = df['date_id'].dt.isocalendar().week
df['day_of_week'] = df['date_id'].dt.weekday + 1 # add 1 for humans:)
df['days_in_month'] = df['date_id'].dt.days_in_month

# boolean attributes
df['is_end_of_month'] = df['date_id'].apply(lambda date: True if pd.Period(date, freq='M').end_time.date() == date else False)
df['is_weekend'] = df['day_of_week'].apply(lambda weekday: True if weekday > 5 else False)
df['is_leap_year'] = df['date_id'].dt.is_leap_year  # another approach .apply(calendar.isleap)
df['is_us_holiday'] = df['date_id'].apply(lambda date: date in us_holidays)
df['is_ua_holiday'] = df['date_id'].apply(lambda date: date in ua_holidays)
df['us_holiday_name'] = df['date_id'].map(us_holidays)
df['ua_holiday_name'] = df['date_id'].map(ua_holidays) # TODO - translate in English on-the-fly?

# calendar year attributes
df[f'{calendar}_month'] = df['date_id'].dt.month
df[f'{calendar}_quarter'] = df['date_id'].dt.quarter
df[f'{calendar}_year'] = df['date_id'].dt.year
df[f'{calendar}_is_eoq'] = df['date_id'].apply(lambda date: True if date == (date - QuarterEnd(startingMonth=0, n=0)).date() else False)
df[f'{calendar}_is_eoy'] = df['date_id'].apply(lambda date: True if date == (date - YearEnd(n=0)).date() else False)
df[f'{calendar}_yyyy_qq'] = df['date_id'].dt.to_period('Q').dt.strftime('%F-Q%q')
df[f'{calendar}_yyyy_mm'] = df['date_id'].dt.strftime('%Y-%m')
df[f'{calendar}_yyyy_mon'] = df['date_id'].dt.strftime('%Y-%b')

# fiscal year attributes
df[f'{fiscal}_month'] = df['date_id'].apply(lambda date: (date - relativedelta(months=1)).month)
df[f'{fiscal}_quarter'] = df['date_id'].dt.to_period('Q-FEB') # use as a RAW source for futher extractions
df[f'{fiscal}_year'] =  df[f'{fiscal}_quarter'].dt.qyear
df[f'{fiscal}_is_eoq'] = df['date_id'].apply(lambda date: True if date == (date - QuarterEnd(startingMonth=1, n=0)).date() else False) # set "startingMonth" arg with offset
df[f'{fiscal}_is_eoy'] = df[[f'{calendar}_month','day_of_month']].apply(lambda row: True if row[0] == 1 and row[1] == 31 else False, axis=1)
df[f'{fiscal}_yyyy_qq'] = df[f'{fiscal}_quarter'].dt.strftime('F%F-Q%q')
df[f'{fiscal}_yyyy_mm'] = pd.to_datetime(df[f'{fiscal}_year'].astype(str) + '-' + df[f'{fiscal}_month'].astype(str)) # # use as a RAW source for futher extractions
df[f'{fiscal}_yyyy_mon'] = df[f'{fiscal}_yyyy_mm'].dt.strftime('F%Y-%b')

# reassign these columns with the values in a proper format
df[f'{fiscal}_yyyy_mm'] = df[f'{fiscal}_yyyy_mm'].dt.strftime('F%Y-%m')
df[f'{fiscal}_quarter'] = df[f'{fiscal}_quarter'].dt.quarter

df.head(31)
# Out:
# CPU times: user 3.83 s, sys: 7.93 ms, total: 3.83 s
# Wall time: 3.83 s
#       date_id month_name weekday_name  day_of_month  day_of_year  \
# 0  2000-01-01    January     Saturday             1            1
# 1  2000-01-02    January       Sunday             2            2
# 2  2000-01-03    January       Monday             3            3
# 3  2000-01-04    January      Tuesday             4            4
# 4  2000-01-05    January    Wednesday             5            5
# 5  2000-01-06    January     Thursday             6            6
# 6  2000-01-07    January       Friday             7            7
# 7  2000-01-08    January     Saturday             8            8
# 8  2000-01-09    January       Sunday             9            9
# 9  2000-01-10    January       Monday            10           10
# 10 2000-01-11    January      Tuesday            11           11
# 11 2000-01-12    January    Wednesday            12           12
# 12 2000-01-13    January     Thursday            13           13
# 13 2000-01-14    January       Friday            14           14
# 14 2000-01-15    January     Saturday            15           15
# 15 2000-01-16    January       Sunday            16           16
# 16 2000-01-17    January       Monday            17           17
# 17 2000-01-18    January      Tuesday            18           18
# 18 2000-01-19    January    Wednesday            19           19
# 19 2000-01-20    January     Thursday            20           20
# 20 2000-01-21    January       Friday            21           21
# 21 2000-01-22    January     Saturday            22           22
# 22 2000-01-23    January       Sunday            23           23
# 23 2000-01-24    January       Monday            24           24
# 24 2000-01-25    January      Tuesday            25           25
# 25 2000-01-26    January    Wednesday            26           26
# 26 2000-01-27    January     Thursday            27           27
# 27 2000-01-28    January       Friday            28           28
# 28 2000-01-29    January     Saturday            29           29
# 29 2000-01-30    January       Sunday            30           30
# 30 2000-01-31    January       Monday            31           31
#
#     week_of_year  day_of_week  days_in_month  is_end_of_month  is_weekend  \
# 0             52            6             31            False        True
# 1             52            7             31            False        True
# 2              1            1             31            False       False
# 3              1            2             31            False       False
# 4              1            3             31            False       False
# 5              1            4             31            False       False
# 6              1            5             31            False       False
# 7              1            6             31            False        True
# 8              1            7             31            False        True
# 9              2            1             31            False       False
# 10             2            2             31            False       False
# 11             2            3             31            False       False
# 12             2            4             31            False       False
# 13             2            5             31            False       False
# 14             2            6             31            False        True
# 15             2            7             31            False        True
# 16             3            1             31            False       False
# 17             3            2             31            False       False
# 18             3            3             31            False       False
# 19             3            4             31            False       False
# 20             3            5             31            False       False
# 21             3            6             31            False        True
# 22             3            7             31            False        True
# 23             4            1             31            False       False
# 24             4            2             31            False       False
# 25             4            3             31            False       False
# 26             4            4             31            False       False
# 27             4            5             31            False       False
# 28             4            6             31            False        True
# 29             4            7             31            False        True
# 30             5            1             31             True       False
#
#     is_leap_year  is_us_holiday  is_ua_holiday             us_holiday_name  \
# 0           True           True           True              New Year's Day
# 1           True          False          False                         NaN
# 2           True          False          False                         NaN
# 3           True          False          False                         NaN
# 4           True          False          False                         NaN
# 5           True          False          False                         NaN
# 6           True          False           True                         NaN
# 7           True          False          False                         NaN
# 8           True          False          False                         NaN
# 9           True          False          False                         NaN
# 10          True          False          False                         NaN
# 11          True          False          False                         NaN
# 12          True          False          False                         NaN
# 13          True          False          False                         NaN
# 14          True          False          False                         NaN
# 15          True          False          False                         NaN
# 16          True           True          False  Martin Luther King Jr. Day
# 17          True          False          False                         NaN
# 18          True          False          False                         NaN
# 19          True          False          False                         NaN
# 20          True          False          False                         NaN
# 21          True          False          False                         NaN
# 22          True          False          False                         NaN
# 23          True          False          False                         NaN
# 24          True          False          False                         NaN
# 25          True          False          False                         NaN
# 26          True          False          False                         NaN
# 27          True          False          False                         NaN
# 28          True          False          False                         NaN
# 29          True          False          False                         NaN
# 30          True          False          False                         NaN
#
#                   ua_holiday_name  calendar_month  calendar_quarter  \
# 0                       Новий рік               1                 1
# 1                             NaN               1                 1
# 2                             NaN               1                 1
# 3                             NaN               1                 1
# 4                             NaN               1                 1
# 5                             NaN               1                 1
# 6   Різдво Христове (православне)               1                 1
# 7                             NaN               1                 1
# 8                             NaN               1                 1
# 9                             NaN               1                 1
# 10                            NaN               1                 1
# 11                            NaN               1                 1
# 12                            NaN               1                 1
# 13                            NaN               1                 1
# 14                            NaN               1                 1
# 15                            NaN               1                 1
# 16                            NaN               1                 1
# 17                            NaN               1                 1
# 18                            NaN               1                 1
# 19                            NaN               1                 1
# 20                            NaN               1                 1
# 21                            NaN               1                 1
# 22                            NaN               1                 1
# 23                            NaN               1                 1
# 24                            NaN               1                 1
# 25                            NaN               1                 1
# 26                            NaN               1                 1
# 27                            NaN               1                 1
# 28                            NaN               1                 1
# 29                            NaN               1                 1
# 30                            NaN               1                 1
#
#     calendar_year  calendar_is_eoq  calendar_is_eoy calendar_yyyy_qq  \
# 0            2000            False            False          2000-Q1
# 1            2000            False            False          2000-Q1
# 2            2000            False            False          2000-Q1
# 3            2000            False            False          2000-Q1
# 4            2000            False            False          2000-Q1
# 5            2000            False            False          2000-Q1
# 6            2000            False            False          2000-Q1
# 7            2000            False            False          2000-Q1
# 8            2000            False            False          2000-Q1
# 9            2000            False            False          2000-Q1
# 10           2000            False            False          2000-Q1
# 11           2000            False            False          2000-Q1
# 12           2000            False            False          2000-Q1
# 13           2000            False            False          2000-Q1
# 14           2000            False            False          2000-Q1
# 15           2000            False            False          2000-Q1
# 16           2000            False            False          2000-Q1
# 17           2000            False            False          2000-Q1
# 18           2000            False            False          2000-Q1
# 19           2000            False            False          2000-Q1
# 20           2000            False            False          2000-Q1
# 21           2000            False            False          2000-Q1
# 22           2000            False            False          2000-Q1
# 23           2000            False            False          2000-Q1
# 24           2000            False            False          2000-Q1
# 25           2000            False            False          2000-Q1
# 26           2000            False            False          2000-Q1
# 27           2000            False            False          2000-Q1
# 28           2000            False            False          2000-Q1
# 29           2000            False            False          2000-Q1
# 30           2000            False            False          2000-Q1
#
#    calendar_yyyy_mm calendar_yyyy_mon  fiscal_month  fiscal_quarter  \
# 0           2000-01          2000-Jan            12               4
# 1           2000-01          2000-Jan            12               4
# 2           2000-01          2000-Jan            12               4
# 3           2000-01          2000-Jan            12               4
# 4           2000-01          2000-Jan            12               4
# 5           2000-01          2000-Jan            12               4
# 6           2000-01          2000-Jan            12               4
# 7           2000-01          2000-Jan            12               4
# 8           2000-01          2000-Jan            12               4
# 9           2000-01          2000-Jan            12               4
# 10          2000-01          2000-Jan            12               4
# 11          2000-01          2000-Jan            12               4
# 12          2000-01          2000-Jan            12               4
# 13          2000-01          2000-Jan            12               4
# 14          2000-01          2000-Jan            12               4
# 15          2000-01          2000-Jan            12               4
# 16          2000-01          2000-Jan            12               4
# 17          2000-01          2000-Jan            12               4
# 18          2000-01          2000-Jan            12               4
# 19          2000-01          2000-Jan            12               4
# 20          2000-01          2000-Jan            12               4
# 21          2000-01          2000-Jan            12               4
# 22          2000-01          2000-Jan            12               4
# 23          2000-01          2000-Jan            12               4
# 24          2000-01          2000-Jan            12               4
# 25          2000-01          2000-Jan            12               4
# 26          2000-01          2000-Jan            12               4
# 27          2000-01          2000-Jan            12               4
# 28          2000-01          2000-Jan            12               4
# 29          2000-01          2000-Jan            12               4
# 30          2000-01          2000-Jan            12               4
#
#     fiscal_year  fiscal_is_eoq  fiscal_is_eoy fiscal_yyyy_qq fiscal_yyyy_mm  \
# 0          2000          False          False       F2000-Q4       F2000-12
# 1          2000          False          False       F2000-Q4       F2000-12
# 2          2000          False          False       F2000-Q4       F2000-12
# 3          2000          False          False       F2000-Q4       F2000-12
# 4          2000          False          False       F2000-Q4       F2000-12
# 5          2000          False          False       F2000-Q4       F2000-12
# 6          2000          False          False       F2000-Q4       F2000-12
# 7          2000          False          False       F2000-Q4       F2000-12
# 8          2000          False          False       F2000-Q4       F2000-12
# 9          2000          False          False       F2000-Q4       F2000-12
# 10         2000          False          False       F2000-Q4       F2000-12
# 11         2000          False          False       F2000-Q4       F2000-12
# 12         2000          False          False       F2000-Q4       F2000-12
# 13         2000          False          False       F2000-Q4       F2000-12
# 14         2000          False          False       F2000-Q4       F2000-12
# 15         2000          False          False       F2000-Q4       F2000-12
# 16         2000          False          False       F2000-Q4       F2000-12
# 17         2000          False          False       F2000-Q4       F2000-12
# 18         2000          False          False       F2000-Q4       F2000-12
# 19         2000          False          False       F2000-Q4       F2000-12
# 20         2000          False          False       F2000-Q4       F2000-12
# 21         2000          False          False       F2000-Q4       F2000-12
# 22         2000          False          False       F2000-Q4       F2000-12
# 23         2000          False          False       F2000-Q4       F2000-12
# 24         2000          False          False       F2000-Q4       F2000-12
# 25         2000          False          False       F2000-Q4       F2000-12
# 26         2000          False          False       F2000-Q4       F2000-12
# 27         2000          False          False       F2000-Q4       F2000-12
# 28         2000          False          False       F2000-Q4       F2000-12
# 29         2000          False          False       F2000-Q4       F2000-12
# 30         2000           True           True       F2000-Q4       F2000-12
#
#    fiscal_yyyy_mon
# 0        F2000-Dec
# 1        F2000-Dec
# 2        F2000-Dec
# 3        F2000-Dec
# 4        F2000-Dec
# 5        F2000-Dec
# 6        F2000-Dec
# 7        F2000-Dec
# 8        F2000-Dec
# 9        F2000-Dec
# 10       F2000-Dec
# 11       F2000-Dec
# 12       F2000-Dec
# 13       F2000-Dec
# 14       F2000-Dec
# 15       F2000-Dec
# 16       F2000-Dec
# 17       F2000-Dec
# 18       F2000-Dec
# 19       F2000-Dec
# 20       F2000-Dec
# 21       F2000-Dec
# 22       F2000-Dec
# 23       F2000-Dec
# 24       F2000-Dec
# 25       F2000-Dec
# 26       F2000-Dec
# 27       F2000-Dec
# 28       F2000-Dec
# 29       F2000-Dec
# 30       F2000-Dec

# %%
df.tail()
# Out:
#          date_id month_name weekday_name  day_of_month  day_of_year  \
# 10953 2029-12-27   December     Thursday            27          361
# 10954 2029-12-28   December       Friday            28          362
# 10955 2029-12-29   December     Saturday            29          363
# 10956 2029-12-30   December       Sunday            30          364
# 10957 2029-12-31   December       Monday            31          365
#
#        week_of_year  day_of_week  days_in_month  is_end_of_month  is_weekend  \
# 10953            52            4             31            False       False
# 10954            52            5             31            False       False
# 10955            52            6             31            False        True
# 10956            52            7             31            False        True
# 10957             1            1             31             True       False
#
#        is_leap_year  is_us_holiday  is_ua_holiday us_holiday_name  \
# 10953         False          False          False             NaN
# 10954         False          False          False             NaN
# 10955         False          False          False             NaN
# 10956         False          False          False             NaN
# 10957         False          False          False             NaN
#
#       ua_holiday_name  calendar_month  calendar_quarter  calendar_year  \
# 10953             NaN              12                 4           2029
# 10954             NaN              12                 4           2029
# 10955             NaN              12                 4           2029
# 10956             NaN              12                 4           2029
# 10957             NaN              12                 4           2029
#
#        calendar_is_eoq  calendar_is_eoy calendar_yyyy_qq calendar_yyyy_mm  \
# 10953            False            False          2029-Q4          2029-12
# 10954            False            False          2029-Q4          2029-12
# 10955            False            False          2029-Q4          2029-12
# 10956            False            False          2029-Q4          2029-12
# 10957             True             True          2029-Q4          2029-12
#
#       calendar_yyyy_mon  fiscal_month  fiscal_quarter  fiscal_year  \
# 10953          2029-Dec            11               4         2030
# 10954          2029-Dec            11               4         2030
# 10955          2029-Dec            11               4         2030
# 10956          2029-Dec            11               4         2030
# 10957          2029-Dec            11               4         2030
#
#        fiscal_is_eoq  fiscal_is_eoy fiscal_yyyy_qq fiscal_yyyy_mm  \
# 10953          False          False       F2030-Q4       F2030-11
# 10954          False          False       F2030-Q4       F2030-11
# 10955          False          False       F2030-Q4       F2030-11
# 10956          False          False       F2030-Q4       F2030-11
# 10957          False          False       F2030-Q4       F2030-11
#
#       fiscal_yyyy_mon
# 10953       F2030-Nov
# 10954       F2030-Nov
# 10955       F2030-Nov
# 10956       F2030-Nov
# 10957       F2030-Nov

# %%
df.sample(10)
# Out:
#          date_id month_name weekday_name  day_of_month  day_of_year  \
# 8309  2022-10-01    October     Saturday             1          274
# 4153  2011-05-16        May       Monday            16          136
# 4990  2013-08-30     August       Friday            30          242
# 2725  2007-06-18       June       Monday            18          169
# 10747 2029-06-04       June       Monday             4          155
# 767   2002-02-06   February    Wednesday             6           37
# 483   2001-04-28      April     Saturday            28          118
# 4630  2012-09-04  September      Tuesday             4          248
# 4037  2011-01-20    January     Thursday            20           20
# 8387  2022-12-18   December       Sunday            18          352
#
#        week_of_year  day_of_week  days_in_month  is_end_of_month  is_weekend  \
# 8309             39            6             31            False        True
# 4153             20            1             31            False       False
# 4990             35            5             31            False       False
# 2725             25            1             30            False       False
# 10747            23            1             30            False       False
# 767               6            3             28            False       False
# 483              17            6             30            False        True
# 4630             36            2             30            False       False
# 4037              3            4             31            False       False
# 8387             50            7             31            False        True
#
#        is_leap_year  is_us_holiday  is_ua_holiday us_holiday_name  \
# 8309          False          False          False             NaN
# 4153          False          False          False             NaN
# 4990          False          False          False             NaN
# 2725          False          False          False             NaN
# 10747         False          False          False             NaN
# 767           False          False          False             NaN
# 483           False          False          False             NaN
# 4630           True          False          False             NaN
# 4037          False          False          False             NaN
# 8387          False          False          False             NaN
#
#       ua_holiday_name  calendar_month  calendar_quarter  calendar_year  \
# 8309              NaN              10                 4           2022
# 4153              NaN               5                 2           2011
# 4990              NaN               8                 3           2013
# 2725              NaN               6                 2           2007
# 10747             NaN               6                 2           2029
# 767               NaN               2                 1           2002
# 483               NaN               4                 2           2001
# 4630              NaN               9                 3           2012
# 4037              NaN               1                 1           2011
# 8387              NaN              12                 4           2022
#
#        calendar_is_eoq  calendar_is_eoy calendar_yyyy_qq calendar_yyyy_mm  \
# 8309             False            False          2022-Q4          2022-10
# 4153             False            False          2011-Q2          2011-05
# 4990             False            False          2013-Q3          2013-08
# 2725             False            False          2007-Q2          2007-06
# 10747            False            False          2029-Q2          2029-06
# 767              False            False          2002-Q1          2002-02
# 483              False            False          2001-Q2          2001-04
# 4630             False            False          2012-Q3          2012-09
# 4037             False            False          2011-Q1          2011-01
# 8387             False            False          2022-Q4          2022-12
#
#       calendar_yyyy_mon  fiscal_month  fiscal_quarter  fiscal_year  \
# 8309           2022-Oct             9               3         2023
# 4153           2011-May             4               1         2012
# 4990           2013-Aug             7               2         2014
# 2725           2007-Jun             5               2         2008
# 10747          2029-Jun             5               2         2030
# 767            2002-Feb             1               4         2002
# 483            2001-Apr             3               1         2002
# 4630           2012-Sep             8               3         2013
# 4037           2011-Jan            12               4         2011
# 8387           2022-Dec            11               4         2023
#
#        fiscal_is_eoq  fiscal_is_eoy fiscal_yyyy_qq fiscal_yyyy_mm  \
# 8309           False          False       F2023-Q3       F2023-09
# 4153           False          False       F2012-Q1       F2012-04
# 4990           False          False       F2014-Q2       F2014-07
# 2725           False          False       F2008-Q2       F2008-05
# 10747          False          False       F2030-Q2       F2030-05
# 767            False          False       F2002-Q4       F2002-01
# 483            False          False       F2002-Q1       F2002-03
# 4630           False          False       F2013-Q3       F2013-08
# 4037           False          False       F2011-Q4       F2011-12
# 8387           False          False       F2023-Q4       F2023-11
#
#       fiscal_yyyy_mon
# 8309        F2023-Sep
# 4153        F2012-Apr
# 4990        F2014-Jul
# 2725        F2008-May
# 10747       F2030-May
# 767         F2002-Jan
# 483         F2002-Mar
# 4630        F2013-Aug
# 4037        F2011-Dec
# 8387        F2023-Nov

# %% [markdown]
# # SAVE TO CSV

# %%
dataset_dir = '../datasets'
os.makedirs(dataset_dir)
df.to_csv(f'{dataset_dir}/dim_dates.csv', index=False)
